# %% [markdown]
# # TEST 4

# %% [markdown]
# ### 1.Предположение i.i.d (независимые одинаково распределенные) обычно применяется к ...
# - признакам
# - наблюдениям [x]
# - значениям целевой переменной

# %% [markdown]
# ### 2. В задаче классификации целевая переменная …
#   Выберите один ответ:
# - принимает значение из конечного множества ответов [x]
# - принимает только целочисленные значения
# - является вектором из действительных чисел

# %% [markdown]
# ### 3.Число соседей в методе kNN является …
# Выберите один ответ:
# - Функцией потерь
# - Гиперпараметром [x]
# - Параметром
# - Метрикой

# %% [markdown]
# ### 4.Метрика в kNN задает …
# Выберите один ответ:
# - способ подсчета расстояний между объектами [x]
# - число соседей, до которых считается расстояние
# - функцию потерь

# %% [markdown]
# ### 5. Какая из предложенных функций может использоваться в качестве метрики?
# Выберите один или несколько ответов:
# - ∥x1−x2∥ <sub>1</sub> [x]
#
# - sin(x1x2)
#
# - exp(x1x2)
#
# - (∥x1−x2∥<sup> 2 </sup>)<sub> 2 </sub> [x]

# %% [markdown]
# ### 6. Наивный Байесовский классификатор является наивным ввиду предположения о ...
# Выберите один ответ:
# - Одинаковой распределенности признаков
# - Независимости признаков [x]
# - Независимости целевой переменной

# %% [markdown]
# ### 7. Пусть случайные величины a и b независимы. Тогда вероятность их произведения p(ab)=…
#
#
# Выберите один ответ:
# - p(a)∗p(b) [x]
#
# - p(a)+p(b)
#
# - p(a)∗p(b)−p(a)−p(b)
#
# - p(a|b)∗p(a)

# %% [markdown]
# ### 8. Формула условной вероятности имеет вид:
# Выберите один ответ:
# - p(a|b)=p(ab)/p(b) [x]
#
# - p(a|b)=p(ab)/p(a)
#
# - p(a|b)=p(ab)∗p(b)

# %% [markdown]
# ### 9. Вероятность выпадения "орла" при подбрасывании монетки
# Выберите один ответ:
# - Растет при увеличении количества выпавших "орлов"
# - Растет при увеличении количества выпавших "решек"
# - Не зависит от предыдущих исходов [x]

# %% [markdown]
# ### 10. Вероятность выпадения хотя бы одного "орла"
# Выберите один ответ:
# - Растет при увеличении кол-ва экспериментов [x]
# - Падает при увеличении кол-ва экспериментов
# - Не зависит от кол-ва экспериментов
