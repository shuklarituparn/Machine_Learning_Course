# %% [markdown]
# ---
# Что такое глифы?
# Выберите один ответ:
# - Отдельные элементы диаграммы, имеющие свои визуальные свойства
# - Несколько диаграмм, каждая из которых состоит из разных элементов
# - Абстрактные символы, не имеющие визуальных свойств
# - Совокупность только точек и линий, составляющих диаграммы
#
# ---

# %% [markdown]
# ---
# Какой из визуальных атрибутов наименее пригоден для отображения точных количественных данных?
# Выберите один ответ:
# - Объем трехмерной фигуры в плоской проекции
# - Угол
# - Насыщенность цвета
# - Позиция на общей шкале
# - Длина двумерного объекта
# ---

# %% [markdown]
# ---
# Чем столбчатая диаграмма отличается от гистограммы?
# Выберите один или несколько ответов:
# - В столбчатой диаграмме используются цвета, а в гистограмме — только черный и белый
# - В столбчатой диаграмме нет расстояния между столбцами, а в гистограмме есть
# - В столбчатой диаграмме столбцы имеют одинаковую ширину, в гистограмме столбцы могут иметь разную ширину
# - В столбчатой диаграмме используются категории на горизонтальной оси, а в гистограмме — числовые значения
# - В столбчатой диаграмме используются только непрерывные переменные, а в гистограмме — только категориальные
# ---

# %% [markdown]
# ---
# Дан график, построенный с помощью функций библиотеки matplotlib:
#
#
#
# Какие настройки внешнего вида графиков были использованы? Выберете все верные варианты ответов.
#
# Выберите один или несколько ответов:
# Настройка типа линии для отображения графика
# Вставка названия графика
# Вставка и настройка легенды
# Удаление подписей горизонтальной и вертикальной осей
# Сделали «невидимой» сетку на поле графика
# ---

# %% [markdown]
# ---
# Вам необходимо построить график синусоиды. Какие строки кода вы будете использовать в своей программе?
#
# Выберите один или несколько ответов:
# - plt.sinusoid()
# - import numpy as np
# - plt.plot(phi, np.sin(phi),)
# - phi = np.linspace(0, 2.*np.pi, 100)
# - import matplotlib.pyplot as plt
# - plt.show()
# ---

# %% [markdown]
# ---
# Какие элементы используются для отображения 3D-объектов в библиотеке NumPy-stl?
# Выберите один или несколько ответов:
# - Векторы
# - Полигоны
# - Вершины
# - Грани
# - Поверхности
# - Оси координат
# - Ребра
# ---

# %% [markdown]
# ---
# Установите в правильной последовательности действия при визуализации в DataLens.
# Выберите один или несколько ответов:
# - Подгрузка датасета
# - Создание подключения
# - Задание доступа (расшаривание)
# - Создание визуализации
# ---

# %% [markdown]
# ---
# В чем состоит основная идеология библиотеки Altair?
# Выберите один или несколько ответов:
# - Использование классов для тонкой настройки графиков
# - Использование HTML-кода для визуализации данных
# - Использование терминологии визуализации данных
# - Возможность сохранения графиков в различных форматах
# ---

# %% [markdown]
# ---
# Какие интерактивные возможности по работе с графиком вы получите после выполнения следующего кода на Python:
#
# ```python
# import altair as alt
# from vega_dataset import data
#
# source=data.cars()
#
# chart=alt.chart(source).mark_bar.encode(
#         x='horsepower',
#         y='miles_per_gallon',
#         color='Origin',
# )
# chart.interactive()
#
#
# ```
#
# Выберите один или несколько ответов:
# - Интерактивная легенда для графика
# - Увеличение или уменьшение графика
# - Динамическое изменение цветовой схемы графика
# - Перемещение по графику с помощью курсора
#
# ---

# %% [markdown]
# ---
#
# Что такое скроллителинг?
# Выберите один ответ:
# - Возможность масштабировать диаграмму и фильтровать данные
# - Метод для создания анимации на диаграммах и графиках
# - Организация линейного повествования на одной веб-странице
# - Прием демонстрации слайдовой презентации
#
# ---

# %% [markdown]
# ---
# Какой паттерн организации пар диаграмм может быть полезен для анализа данных в разных ракурсах?
# Выберите один ответ:
# - «Связанные между собой диаграммы»
# - «Обзор + детали»
# - «Диаграмма + таблица»
# - «Что-где-когда»
# ---

# %% [markdown]
# ---
#
# Какие пункты соответствуют правилам создания эффективных презентаций?
# Выберите один или несколько ответов:
# - Текст на слайде должен повторять голос докладчика
# - Один слайд — одно сообщение или часть этого сообщения
# - Необходимо использовать как можно больше цветов на слайде
# - Всю информацию о диаграмме нужно описывать текстом на слайде
# - Каждый слайд должен быть сформирован для конкретной цели
#
# ---

# %% [markdown]
# ---
#
# Какое из утверждений, описывающих возможности дашбордов в Yandex DataLens, верное?
# Выберите один ответ:
# - Фильтры размещаются только в нижней части дашборда
# - На дашборд можно добавлять фильтры по категориям
# - В дашбордах нельзя менять расположение графиков
# - Дашборды не могут содержать ссылки на графики, построенные заранее
# - Дашборды могут содержать только диаграммы
#
# ---

# %% [markdown]
# ---
#
# Что происходит с графиком в презентации HTML, если меняется датасет или стиль графика в Yandex DataLens?
# Выберите один или несколько ответов:
# - График исчезает из презентации насовсем
# - График обновляется только при перезагрузке страницы
# - График обновляется только после редактирования файла HTML
# - График обновляется автоматически по ссылке в презентации
#
# ---

# %% [markdown]
# ---
# Каким образом можно вставить график из Yandex DataLens в презентацию Reveal.js?
# Выберите один ответ:
# - Скопировать код графика и вставить его в тег <code>
# - Экспортировать график в формате .png и вставить его на слайд
# - Скопировать картинку графика и вставить ее в тег `<img>`
# - Скопировать ссылку на график и вставить ее в тег <iframe>
# - Вставить график в формате .xls или .csv на слайд
# ---

# %% [markdown]
# ---
# Что нужно написать в Altair, чтобы настроить использование цвета глифа для отображения некоторого атрибута данных?
# Выберите один ответ:
# - .set(...hue=...)
# - .rgb(#...)
# - .encode(...color=...)
# - .params(...color=...)
# - .color(hue=..., lightness=..., saturation=...)
# ---

# %% [markdown]
# ---
# Можно ли некоторые фрагменты слайда в Reveal.js указать как видимые не сразу при отображении слайда, а по щелчку?
# Выберите один ответ:
# - Нет, это не поддерживается
# - Да, достаточно добавить стилевой класс fragment
# - Да, достаточно оформить такие фрагменты, как нумерованный список
# - Да, достаточно указать фрагмент в теге section
# - Нет, но это можно сделать средствами Altair
#
# ---

# %% [markdown]
# ---
# Какой вывод можно сделать из матрицы корреляции, если значение коэффициента корреляции между двумя параметрами равно 0,25?
# Выберите один ответ:
# - Отсутствие связи
# - Сильная отрицательная связь
# - Слабая отрицательная связь
# - Сильная положительная связь
# - Слабая положительная связь
#
# ---

# %% [markdown]
# ---
# Какой метод следует использовать для генерации новых признаков при категоризации?
# Выберите один ответ:
# - get_unic()
# - merge()
# - hist()
# - get_dummies()
# ---
